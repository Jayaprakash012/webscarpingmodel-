# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayaprakash012/webscarpingmodel-/blob/main/Webscarping2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # web sscarping\

# %%
 import pandas as pd
 import requests
 import bs4 as Beautifulsoup

# %%
 webpage = request.get("https://www.imdb.com/chart/top/?ref_=nv_mv_250")
 soup = BeautifulSoup(webpage,'lxml')

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
db.com/chart/top/?ref_=nv_mv_250').textwebpage = requests.get('https://www.im
soup = BeautifulSoup(webpage,'lxml')

# %%
print(webpage)

# %%
headers=headers{'User-Agent':'Mozilla/5.0 (Windows NT 7.2; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 7.2; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage = requests.get('https://www.imdb.com/chart/top/?ref_=nv_mv_250',headers = headers).text

# %%
print (webpage)

# %%
l = soup.find_all("h3,"<div class="ipc-title_text")
print (1)

# %%
print (webpage)
